# %% [markdown]
# 1. Line Chart
# Best for: Displaying trends over time or continuous data.
#
# Data type: Time series, sequential data, or continuous variables.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Example data
data = pd.Series([1, 3, 2, 4, 5, 6, 4], index=pd.date_range("2025-01-01", periods=7))

plt.plot(data)
plt.title('Line Chart Example')
plt.xlabel('Date')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %% [markdown]
# 2. Bar Chart
# Best for: Comparing quantities across different categories.
#
# Data type: Categorical data or discrete data.
# python
# Copy

# %%
import matplotlib.pyplot as plt

# Example data
categories = ['A', 'B', 'C', 'D']
values = [23, 45, 56, 78]

plt.bar(categories, values)
plt.title('Bar Chart Example')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# 3. Histogram
# Best for: Showing the distribution of numerical data.
#
# Data type: Continuous data to visualize its distribution.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
data = np.random.randn(1000)

plt.hist(data, bins=30, edgecolor='black')
plt.title('Histogram Example')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
